# %%
def greet(name):
    return f"Hello, {name}!"
print(greet("walid"))
# Out:
# Hello, walid!

# %%
def calculate_area(length, width):
    return length * width

area = calculate_area(10, 20)
print(area)
# Out:
# 200

# %%
import math
print ( math . sqrt (42) )
# Out:
# 6.48074069840786

# %%
def find_largest(a, b, c):
    return max(a, b, c)

print(find_largest(2, 15, 5))
# Out:
# 15

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)

print(factorial(6))
# Out:
# 720

# %%
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    return a / b if b != 0 else "Division by zero error"
    from math_operations import add, subtract, multiply, divide


print(add(5, 3))
print(subtract(10, 4))
print(multiply(6, 7))
print(divide(20, 4))
# Out:
# 8
# 6
# 42
# 5.0

# %%
code = """
def greet(name):
    return f"Hello, {name}!"

def add(a, b):
    return a + b

def subtract(a, b):
    return a - b
"""
with open('mymodule.py', 'w') as f:
    f.write(code)
import mymodule
print(mymodule.greet("walid"))
print(mymodule.add(10, 5))
print(mymodule.subtract(20, 8))
# Out:
# Hello, walid!
# 15
# 12
