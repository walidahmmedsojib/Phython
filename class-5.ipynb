# %%
a=int (input("enter value a="))
b=int(input("enter value b="))
sum=a+b;
mod=a%b;

print("sum= ",sum,"mod= ",mod);
# Out:
# enter value a=2
# enter value b=5
# sum=  7 mod=  2

# %%
a=int(input("enter your grade="))
if (a>=80 and a<=100):
   print("your grade is A+")
elif (a>=75 and a<80):
   print("your grade is A")
elif (a>=70 and a<75):
   print("your grade is A-")
elif (a>=65 and  a<70):
   print("your grade is B+")
elif (a>=60 and a<65):
   print("your grade is B-")
elif (a>=55 and a<60):
   print("your grade is C+")
elif (a>=50 and a<55):
   print("your grade is C-")

elif (a>=40 and a<50):
   print("your grade is D")

elif(a<40):
   print("\n your are Failed (- -)")
# Out:
# enter your grade=33
#
#  your are Failed (- -)

# %%
for num in range(0):
    if num==2:
       pass
    print(num)

for num1 in range(5):
    if num1 % 2 == 0:
       continue
    print(num1)
# Out:
# 1
# 3

# %%
a= float (input("enter your value of a:"))
b= float (input("enter your value of b:"))
c=float (input("enter your value of c:"))

largest=max(a,b,c)
print(f"{largest}")
# Out:
# enter your value of a:3
# enter your value of b:6
# enter your value of c:5
# 6.0

# %%
a=int(input("enter a value"))
square=a*a
print(square)
# Out:
# enter a value3
# 9

# %%
a=int (input("enter a value" ))
po=a**2
print(po)
# Out:
# enter a value2
# 4
