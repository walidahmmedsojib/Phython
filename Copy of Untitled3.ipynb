# %%
class Car:
    def __init__(self, model, year):
        self.model = model
        self.year = year

    def start_engine(self):
        return f"The {self.model} ({self.year}) engine has started."

my_car = Car("Toyota", 2020)
print(my_car.start_engine())
# Out:
# The Toyota (2020) engine has started.

# %%
class Student:
    def __init__(self, name, ID, Dept):
        self.name = name
        self.ID = ID
        self.Dept = Dept

    def start_B_Sc(self):
        return f" name {self.name},  ID {self.ID},  department  {self.Dept}."



student_inf = Student("walid", 231902042, "CSE")
print(student_inf.start_B_Sc())

student_inf = Student("Maju", 231902057, "CSE")
print(student_inf.start_B_Sc())

student_inf = Student("rahul", 231902058, "CSE")
print(student_inf.start_B_Sc())

student_inf = Student("raisul", 231902059, "CSE")
print(student_inf.start_B_Sc())

student_inf = Student("mahin", 231902060, "CSE")
print(student_inf.start_B_Sc())

student_inf = Student("aslam", 231902061, "CSE")
print(student_inf.start_B_Sc())

student_inf = Student("sumon", 231902056, "CSE")
print(student_inf.start_B_Sc())

student_inf = Student("fariya", 231902056, "CSE")
print(student_inf.start_B_Sc())

student_inf = Student("rima", 231902056, "CSE")
print(student_inf.start_B_Sc())

student_inf = Student("tabasum", 231902056, "CSE")
print(student_inf.start_B_Sc())

student_inf = Student("rumel", 231902056, "CSE")
print(student_inf.start_B_Sc())

student_inf = Student("mofiz", 231902056, "CSE")
print(student_inf.start_B_Sc())
# Out:
#  name walid,  ID 231902042,  department  CSE.
#  name Maju,  ID 231902057,  department  CSE.
#  name rahul,  ID 231902058,  department  CSE.
#  name raisul,  ID 231902059,  department  CSE.
#  name mahin,  ID 231902060,  department  CSE.
#  name aslam,  ID 231902061,  department  CSE.
#  name sumon,  ID 231902056,  department  CSE.
#  name fariya,  ID 231902056,  department  CSE.
#  name rima,  ID 231902056,  department  CSE.
#  name tabasum,  ID 231902056,  department  CSE.
#  name rumel,  ID 231902056,  department  CSE.
#  name mofiz,  ID 231902056,  department  CSE.

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

    def perimeter(self):
        return 2 * (self.length + self.width)



rect = Rectangle(10, 5)
print(rect.area())
print(rect.perimeter())
# Out:
# 50
# 30

# %%
class BankAccount:
    def __init__(self, account_number, balance=0):
        self.account_number = account_number
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            return "Insufficient funds"

    def get_balance(self):
        return self.balance


account = BankAccount(101, 1000)
account.deposit(500)
print(account.get_balance())
account.withdraw(200)
print(account.get_balance())
# Out:
# 1500
# 1300

# %%
class BankAccount:
    def __init__(self, account_number, balance=0):
        self.account_number = account_number
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if self.balance >= amount:
            self.balance -= amount
        else:
            return "Insufficient funds"

    def get_balance(self):
        return self.balance


class Bank:
    def __init__(self):
        self.accounts = []

    def add_account(self, account):
        self.accounts.append(account)

    def total_funds(self):
        return sum(account.get_balance() for account in self.accounts)


account1 = BankAccount(101, 1000)
account2 = BankAccount(102, 1500)
bank = Bank()
bank.add_account(account1)
bank.add_account(account2)
print(bank.total_funds())
# Out:
# 2500

# %%
class Animal:
    def sound(self):
        pass


class Dog(Animal):
    def sound(self):
        print("Bark")


class Cat(Animal):
    def sound(self):
        print("Meow")


dog = Dog()
dog.sound()

cat = Cat()
cat.sound()
# Out:
# Bark
# Meow
