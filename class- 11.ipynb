# %%
from datetime import date

d0 = date(2008,8,17)

d1=  date(2008,9,27)


delta = d1-d0

print(delta.days)
# Out:
# 41

# %%
age1 = (input ("Enter your age :"))

sec  = age1*365*24*3600

print("your age is =",sec)
# Out:
# Buffered data was truncated after reaching the output size limit.
